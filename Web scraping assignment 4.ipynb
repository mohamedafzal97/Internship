# %% [markdown]
# # Web scraping assignment 4

# %%
! pip install selenium
# Out:
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
#importing all required libraries
import selenium                # library to work with selenium
from selenium import webdriver # library to open up automated chrome window
from selenium.webdriver.common.by import By
import pandas as pd            # to make dataframe
import numpy as np             # to make numerical operations
import time                    # to stop search enginge for few seconds
import warnings
warnings.filterwarnings('ignore')  # ignores any kind of warnings
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# first connect to the web driver
driver1=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver1.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
data1 = driver1.find_elements(By.XPATH, '//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td')

Data1 = []

for i in data1[:179]:

    Data1.append(i.text)

# %%
rank1=[]
name1=[]
artist1=[]
upload_date1=[]
views1=[]

rank1=Data1[:72:6]+Data1[72::6]

name1=Data1[1:72:6]+Data1[73::6]

artist1=Data1[2:72:6]+Data1[74::6]

upload_date1=Data1[4:72:6]+Data1[76::6]

views1=Data1[3:72:6]+Data1[75::6]

# %%
# checking length
len(rank1), len(name1), len(artist1), len(upload_date1), len(views1)
# Out:
# (30, 30, 30, 30, 30)

# %%
driver1.close()

# %%
# creating dataframe
dt={'Rank':rank1,'Name':name1,'Artist':artist1,'Upload_date':upload_date1,'Views':views1}
youtube_df1=pd.DataFrame(dt)

# dataframe
youtube_df1
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# =====================================================================================================================

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time

# %%
# first connect to the web driver
driver2=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver2.get('https://www.bcci.tv/')

# %%
international = driver2.find_element(By.XPATH, '/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international.click()

# %%
Match_title2=[]
Series2=[]
Place2=[]
Date2=[]
Time2=[]

match_title2 = driver2.find_elements(By.XPATH, '//span[@class="matchOrderText ng-binding ng-scope"]')
for i in match_title2:
    Match_title2.append(i.text.replace('-',''))


series2 = driver2.find_elements(By.XPATH, '//span[@class="ng-binding"]')
for i in series2:
    Series2.append(i.text)
    

place2 = driver2.find_elements(By.XPATH, '//span[@class="ng-binding ng-scope"]')
for i in place2:
    Place2.append(i.text)

    
date2 = driver2.find_elements(By.XPATH, '//h5[@class="ng-binding"]')
for i in date2:
    Date2.append(i.text)

    
time2 = driver2.find_elements(By.XPATH, '//h5[@class="text-right ng-binding"]')
for i in time2:
    Time2.append(i.text)

# %%
len(Match_title2), len(series2), len(Place2), len(Date2), len(Time2)
# Out:
# (4, 4, 4, 4, 4)

# %%
# creating dataframe
dt2={'Match_title':Match_title2,'Series':Series2,'Place':Place2,'Date':Date2,'Time':Time2}
cricket_df2=pd.DataFrame(dt2)

# dataframe
cricket_df2
# Out:
#   Match_title                                         Series  \
# 0    1st ODI   INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022
# 1   5th Test          INDIA TOUR OF ENGLAND TEST SERIES 2021
# 2    2nd ODI   INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022
# 3    3rd ODI   INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022
#
#                                       Place        Date          Time
# 0  Pallekele International Cricket Stadium,  1 JUL 2022  10:00 AM IST
# 1                                Edgbaston,  1 JUL 2022   3:00 PM IST
# 2  Pallekele International Cricket Stadium,  4 JUL 2022  10:00 AM IST
# 3  Pallekele International Cricket Stadium,  7 JUL 2022  10:00 AM IST

# %%
driver2.close()

# %% [markdown]
# ======================================================================================================================

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description

# %%
# first connect to the web driver
driver3=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver3.get('https://www.guru99.com/')
time.sleep(10)

# %%
#finding elements for user input
search_=driver3.find_element(By.XPATH, '/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input')
search_.send_keys('selenium exception handling')

# %%
search_button=driver3.find_element(By.XPATH, '/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button')
search_button.click()

# %%
for _ in range(20):
    driver3.execute_script('window.scrollBy(0,3)')

# %%
#scraping  url    
Exception_url=[]    
exception_url=driver3.find_elements(By.XPATH,'//a[@class="gs-title"]')
for d in exception_url[1:2]:
    Exception_url.append(d.get_attribute('href'))

# %%
Exception_url
# Out:
# ['https://www.guru99.com/exception-handling-selenium.html']

# %%
driver3.close()

# %%
Data3=[]

for i in Exception_url:
    driver=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
    driver.get(i)
    time.sleep(5)
    
    data_tags=driver.find_elements(By.XPATH, '//table[@class="table table-striped"]/tbody/tr/td')
    for j in data_tags:
        Data3.append(j.text)
        
    driver.close()

# %%
Name3=Data3[:82:2]
Description3=Data3[1:82:2]

# %%
len(Name3), len(Description3)
# Out:
# (41, 41)

# %%
# creating dataframe
dt3={'Name':Name3,'Description':Description3}
Exception_df3=pd.DataFrame(dt3)

# dataframe
Exception_df3
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# ====================================================================================================================

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)

# %%
# first connect to the web driver
driver4=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver4.get('https://www.statisticstimes.com/')

# %%
#clicking on economy
economy=driver4.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy.click()

# %%
India=driver4.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
India.click()

# %%
state_gdp=driver4.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
state_gdp.click()
time.sleep(10)

# %%
rank4 = driver4.find_elements(By.XPATH, '//td[@class="data1"]')

Rank4 = []

for i in rank4[:33]:

    Rank4.append(i.text)
    
    
state4 = driver4.find_elements(By.XPATH, '//td[@class="name"]')

State4 = []

for i in state4[:33]:

    State4.append(i.text)
    
    
gsdp_18_19 = driver4.find_elements(By.XPATH, '//td[@class="data sorting_1"]')

GSDP_18_19 = []

for i in gsdp_18_19[:33]:

    GSDP_18_19.append(i.text)
    

    
data4= driver4.find_elements(By.XPATH, '//td[@class="data"]')

Data4= []

for i in data4:

    Data4.append(i.text)

# %%
GSDP_19_20=Data4[0:161:5]
Share_18_19=Data4[1:162:5]
GDP_billion=Data4[2:163:5]
GSDP_Cr_INR_at_2011_12_prices_19_20=Data4[3:164:5]
GSDP_Cr_INR_at_2011_12_prices_18_19=Data4[4:165:5]

# %%
len(Rank4), len(State4), len(GSDP_18_19), len(GSDP_19_20), len(Share_18_19), len(GDP_billion), len(GSDP_Cr_INR_at_2011_12_prices_19_20), len(GSDP_Cr_INR_at_2011_12_prices_18_19)
# Out:
# (33, 33, 33, 33, 33, 33, 33, 33)

# %%
driver4.close()

# %%
# creating dataframe
dt4={'Rank':Rank4,'State':State4, 'GSDP_19-20(Cr INR at Current prices)':GSDP_19_20,'GSDP_18-19(Cr INR at Current prices)':GSDP_18_19,'Share_18_19':Share_18_19, 'GDP($billion)':GDP_billion, 'GSDP_19-20(Cr INR at 2011-12 prices)':GSDP_Cr_INR_at_2011_12_prices_19_20,'GSDP_18-19( (Cr INR at 2011-12 prices)':GSDP_Cr_INR_at_2011_12_prices_18_19}
Indian_state_wise_GDP_df3=pd.DataFrame(dt4)

# dataframe
Indian_state_wise_GDP_df3
# Out:
#    Rank                      State GSDP_19-20(Cr INR at Current prices)  \
# 0     1                Maharashtra                                    -
# 1     2                 Tamil Nadu                            1,845,853
# 2     3              Uttar Pradesh                            1,687,818
# 3     4                    Gujarat                                    -
# 4     5                  Karnataka                            1,631,977
# 5     6                West Bengal                            1,253,832
# 6     7                  Rajasthan                            1,020,989
# 7     8             Andhra Pradesh                              972,782
# 8     9                  Telangana                              969,604
# 9    10             Madhya Pradesh                              906,672
# 10   11                     Kerala                                    -
# 11   12                      Delhi                              856,112
# ...

# %% [markdown]
# =======================================================================================================================

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
# first connect to the web driver
driver5=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver5.get('https://github.com/')

# %%
#clicking on explore
explore=driver5.find_element(By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
explore.click()

# %%
# clicking trending
trending=driver5.find_element(By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
trending.click()

# %%
tittle5 = driver5.find_elements(By.XPATH, '//h1[@class="h3 lh-condensed"]')

Tittle5 = []

for i in tittle5:

    Tittle5.append(i.text)

# %%
description5 = driver5.find_elements(By.XPATH, '//p[@class="col-9 color-fg-muted my-1 pr-4"]')

Description5 = []

for i in description5:

    Description5.append(i.text)

# %%
contributors5 = driver5.find_elements(By.XPATH, '//a[@class="Link--muted d-inline-block mr-3"]')

Contributors5 = []

for i in contributors5[1::2]:

    Contributors5.append(i.text)

# %%
language5 = driver5.find_elements(By.XPATH, '//span[@class="d-inline-block ml-0 mr-3"]')

Language5 = []

for i in language5:
    if (i.text==None):
        Language5.append('-')
    else:
        Language5.append(i.text)

# %%
Language5.insert(3, '-')
Language5.insert(4, '-')
Language5.insert(17, '-')
Language5.insert(19,'-')

# %%
len(Tittle5), len(Description5), len(Contributors5), len(Language5)
# Out:
# (25, 25, 25, 25)

# %%
driver5.close()

# %%
# creating dataframe
dt5={' Repository title':Tittle5,'Repository description':Description5, 'Contributors count':Contributors5, 'Language used':Language5 }
github_df5=pd.DataFrame(dt5)

# dataframe
github_df5
# Out:
#                               Repository title  \
# 0                             delta-io / delta
# 1                             denoland / fresh
# 2                     Azure / azureml-examples
# 3                    dair-ai / ML-Course-Notes
# 4   edoardottt / awesome-hacker-search-engines
# 5                                    qq8e / qq
# 6              bregman-arie / devops-exercises
# 7                             facebook / folly
# 8                      storybookjs / storybook
# 9                           jinfagang / yolov7
# 10                           ascoders / weekly
# 11                                 D3Ext / WEF
# 12                           remix-run / remix
# 13                               dotnet / maui
# 14                         directus / directus
# 15     aolofsson / awesome-opensource-hardware
# 16      GrowingGit / GitHub-Chinese-Top-Charts
# 17          Hack-with-Github / Awesome-Hacking
# 18                MichaelCade / 90DaysOfDevOps
# ...

# %% [markdown]
# 6. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board

# %%
#first connect to webdriver
driver6=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver6.get('https://www.billboard.com/')

# %%
#clicking on charts
charts=driver6.find_element(By.XPATH, '/html/body/div[3]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a')
charts.click()

# %%
#clicking on hot 100
hot_1oo=driver6.find_element(By.XPATH, '/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a')
hot_1oo.click()

# %%
name5 = driver6.find_elements(By.XPATH, '//li[@class="lrv-u-width-100p"]//h3')

Name5 = []

for i in name5:

    Name5.append(i.text)

# %%
week_rank5 = driver6.find_elements(By.XPATH, '//li[@class="lrv-u-width-100p"]//span')

Week_rank5 = []

for i in week_rank5[1::7]:

    Week_rank5.append(i.text)

# %%
artist5 = driver6.find_elements(By.XPATH, '//li[@class="lrv-u-width-100p"]//span')

Artist5 = []

for i in artist5[::7]:

    Artist5.append(i.text)

# %%
peak_rank5 = driver6.find_elements(By.XPATH, '//li[@class="lrv-u-width-100p"]//span')

Peak_rank5 = []

for i in peak_rank5[2::7]:

    Peak_rank5.append(i.text)

# %%
weeks_on_board5 = driver6.find_elements(By.XPATH, '//li[@class="lrv-u-width-100p"]//span')

Weeks_on_board5 = []

for i in weeks_on_board5[3::7]:

    Weeks_on_board5.append(i.text)

# %%
len(Name5), len(Week_rank5), len(Artist5), len(Peak_rank5), len(Weeks_on_board5)
# Out:
# (100, 100, 100, 100, 100)

# %%
driver6.close()

# %%
# creating dataframe
dt6={'Song_name':Name5,'Artist_name':Artist5, 'Last_Week_rank':Week_rank5, 'Peak_rank':Peak_rank5, 'Weeks_on_board':Weeks_on_board5 }
Billiboard_df6=pd.DataFrame(dt6)

# dataframe
Billiboard_df6
# Out:
#                Song_name                        Artist_name Last_Week_rank  \
# 0            Jimmy Cooks          Drake Featuring 21 Savage              -
# 1              As It Was                       Harry Styles              1
# 2            First Class                        Jack Harlow              2
# 3             Wait For U      Future Featuring Drake & Tems              3
# 4        About Damn Time                              Lizzo              4
# ..                   ...                                ...            ...
# 95                   N95                     Kendrick Lamar             72
# 96          Love Me More                          Sam Smith             93
# 97             New Truck                        Dylan Scott             99
# 98  She's All I Wanna Be                         Tate McRae             68
# 99          Desesperados  Rauw Alejandro & Chencho Corleone             94
#
#    Peak_rank Weeks_on_board
# 0          1              1
# ...

# %% [markdown]
# ======================================================================================================================

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location

# %%
#first connect to webdriver
driver7=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver7.get('https://www.naukri.com/')

# %%
#clicking on charts
search_box=driver7.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[3]/div/div/div[1]/div/div/div/input')
search_box.send_keys('Data science')

# %%
click_search=driver7.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[3]/div/div/div[6]')
click_search.click()

# %%
recruiters=driver7.find_element(By.XPATH, '/html/body/div[1]/div[1]/div/ul[1]/li[2]/a/div')
recruiters.click()

# %%
driver7.get('https://www.naukri.com/hr-recruiters-consultants')

# %%
#clicking on charts
search_boxa=driver7.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
search_boxa.send_keys('Data science')

# %%
click_search=driver7.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
click_search.click()

# %%
name7 = driver7.find_elements(By.XPATH, '//span[@class="fl ellipsis"]')

Name7 = []

for i in name7:

    Name7.append(i.text)

# %%
designation7 = driver7.find_elements(By.XPATH, '//span[@class="ellipsis clr"]')

Designation7 = []

for i in designation7:

    Designation7.append(i.text)

# %%
company7 = driver7.find_elements(By.XPATH, '//a[@class="ellipsis"]')

Company7 = []

for i in company7[1::2]:

    Company7.append(i.get_attribute('title'))

# %%
skills7 = driver7.find_elements(By.XPATH, '//div[@class="hireSec highlightable"]')

Skills7 = []

for i in skills7:

    Skills7.append(i.text)

# %%
location7 = driver7.find_elements(By.XPATH, '//small[@class="ellipsis"]')

Location7 = []

for i in location7:
    Location7.append(i.text)

# %%
Location7.insert(28, '-')
Location7.insert(48, '-')

# %%
len(Name7), len(Designation7), len(Company7), len(Skills7), len(Location7)
# Out:
# (50, 50, 50, 50, 50)

# %%
driver7.close()

# %%
# creating dataframe
dt7={'Name':Name7,'Designation':Designation7, 'Company':Company7, 'Skills_required':Skills7, 'Location':Location7 }
Naukri_df7=pd.DataFrame(dt7)

# dataframe
Naukri_df7
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                   Kapil Devang
# 16                                Sakshi Chhikara
# 17                                    Ruchi Dhote
# ...

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#first connect to webdriver
driver8=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver8.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
name8 = driver8.find_elements(By.XPATH, '//td[@class="left"]')

Name8 = []

for i in name8[1::5]:

    Name8.append(i.text)

# %%
author8 = driver8.find_elements(By.XPATH, '//td[@class="left"]')

Author8 = []

for i in author8[2::5]:

    Author8.append(i.text)

# %%
volumes_sold8 = driver8.find_elements(By.XPATH, '//td[@class="left"]')

Volumes_sold8 = []

for i in volumes_sold8[3::5]:

    Volumes_sold8.append(i.text)

# %%
publisher8 = driver8.find_elements(By.XPATH, '//td[@class="left"]')

Publisher8 = []

for i in publisher8[4::5]:

    Publisher8.append(i.text)

# %%
genre8 = driver8.find_elements(By.XPATH, '//td[@class="last left"]')

Genre8 = []

for i in genre8:

    Genre8.append(i.text)

# %%
len(Name8), len(Author8), len(Volumes_sold8), len(Publisher8), len(Genre8)
# Out:
# (100, 100, 100, 100, 100)

# %%
driver8.close()

# %%
# creating dataframe
dt8={'Book_name':Name8,'Author_name':Author8, 'Volumes_sold':Volumes_sold8, 'Publisher':Publisher8, 'Genre':Genre8}
Books_df8=pd.DataFrame(dt8)

# dataframe
Books_df8
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#first connect to webdriver
driver9=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver9.get('https://www.imdb.com/list/ls095964455/')

# %%
name9 = driver9.find_elements(By.XPATH, '//h3[@class="lister-item-header"]/a')

Name9 = []

for i in name9:

    Name9.append(i.text)

# %%
year_span9 = driver9.find_elements(By.XPATH, '//span[@class="lister-item-year text-muted unbold"]')

Year_span9 = []

for i in year_span9:

    Year_span9.append(i.text)

# %%
genre9 = driver9.find_elements(By.XPATH, '//span[@class="genre"]')

Genre9 = []

for i in genre9:

    Genre9.append(i.text)

# %%
run_time9 = driver9.find_elements(By.XPATH, '//span[@class="runtime"]')

Run_time9 = []

for i in run_time9:

    Run_time9.append(i.text.replace('min',''))

# %%
ratings9 = driver9.find_elements(By.XPATH, '//span[@class="ipl-rating-star__rating"]')

Ratings9 = []

for i in ratings9[0::23]:

    Ratings9.append(i.text)

# %%
votes9 = driver9.find_elements(By.XPATH, '//p[@class="text-muted text-small"]')

Votes9 = []

for i in votes9[2::3]:

    Votes9.append(i.text.replace('Votes: ',''))

# %%
len(Name9), len(Year_span9), len(Genre9), len(Run_time9), len(Ratings9), len(Votes9)
# Out:
# (100, 100, 100, 100, 100, 100)

# %%
driver9.close()

# %%
# creating dataframe
dt9={'Name':Name9,'Year_span':Year_span9, 'Genre':Genre9, 'Run_time':Run_time9, 'Ratings':Ratings9, 'Votes': Votes9 }
IMDB_df9=pd.DataFrame(dt9)

# dataframe
IMDB_df9
# Out:
#                               Name    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Ratings      Votes
# 0       57      9.2  2,001,934
# ...

# %% [markdown]
# ==================================================================================================================

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
#first connect to webdriver
driver10=webdriver.Chrome(r'C:\Users\Ismail\Desktop\chromedriver.exe')
time.sleep(5)

# %%
# opening up website on automated webdriver
driver10.get('https://archive.ics.uci.edu/ml/index.php')

# %%
all_dataset=driver10.find_element(By.XPATH, '/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b')
all_dataset.click()

# %%
dataset_name10 = driver10.find_elements(By.XPATH, '//p[@class="normal"]/b/a')

Dataset_name10 = []

for i in dataset_name10:

    Dataset_name10.append(i.text)

# %%
datatype10 = driver10.find_elements(By.XPATH, '//p[@class="normal"]')

Datatype10 = []

for i in datatype10[9:4363:7]:
    if (i.text==' '):
        Datatype10.append('-')
    else:
        Datatype10.append(i.text)

# %%
task10 = driver10.find_elements(By.XPATH, '//p[@class="normal"]')

Task10 = []

for i in task10[10:4363:7]:
    if (i.text==' '):
        Task10.append('-')
    else:
        Task10.append(i.text)

# %%
attribute10 = driver10.find_elements(By.XPATH, '//p[@class="normal"]')

Attribute10 = []

for i in attribute10[11:4363:7]:
    if (i.text==' '):
        Attribute10.append('-')
    else:
        Attribute10.append(i.text)

# %%
instances10 = driver10.find_elements(By.XPATH, '//p[@class="normal"]')

Instances10 = []

for i in instances10[12:4363:7]:
    if (i.text==' '):
        Instances10.append('-')
    else:
        Instances10.append(i.text)

# %%
no_of_attribute10 = driver10.find_elements(By.XPATH, '//p[@class="normal"]')

No_of_attribute10 = []

for i in no_of_attribute10[13:4363:7]:
    if (i.text==' '):
        No_of_attribute10.append('-')
    else:
        No_of_attribute10.append(i.text)

# %%
year10 = driver10.find_elements(By.XPATH, '//p[@class="normal"]')

Year10 = []

for i in year10[14:4363:7]:
    if (i.text==' '):
        Year10.append('-')
    else:
        Year10.append(i.text)

# %%
len(Dataset_name10), len(Datatype10), len(Task10), len(Attribute10), len(Instances10), len(No_of_attribute10),  len(Year10)
# Out:
# (622, 622, 622, 622, 622, 622, 622)

# %%
driver10.close()

# %%
# creating dataframe
dt10={'Dataset_name':Dataset_name10,'Data_type':Datatype10, 'Task':Task10, 'Attribute_type':Attribute10, 'No_of_Instances':Instances10, 'No_of_attributes': No_of_attribute10, 'Year':Year10 }
Dataset_df10=pd.DataFrame(dt10)

# dataframe
Dataset_df10
# Out:
#                                           Dataset_name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data_type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                             -  Recommender-Systems
# ...
